# %%
class Mueble:
  def __init__(self, id, proveedor, precio, tipo_madera, ubicacion, color, propietario, tamaño_mueble):
    self.__id = id
    self.__proveedor = proveedor
    self.__precio = precio
    self.__tipo_madera = tipo_madera
    self.__ubicacion = ubicacion
    self.__color = color
    self.__propietario = propietario
    self.__tamaño_mueble = tamaño_mueble

  def get_id(self):
    return self.__id

  def set_id(self, id):
    if id < 0:
      raise ValueError("El id no puede ser negativo")
    self.__id = id

  def get_proveedor(self):
    return self.__proveedor

  def set_proveedor(self, proveedor):
    if not proveedor or not isinstance(proveedor, str):
      raise ValueError("El proveedor no puede estar vacío y debe ser una cadena de texto")
    self.__proveedor = proveedor

  def get_precio(self):
    return self.__precio

  def set_precio(self, precio):
    if precio < 0:
      raise ValueError("El precio no puede ser negativo")
    self.__precio = precio

  def get_tipo_madera(self):
    return self.__tipo_madera

  def set_tipo_madera(self, tipo_madera):
    if not tipo_madera or not isinstance(tipo_madera, str):
      raise ValueError("El tipo de madera no puede estar vacío y debe ser una cadena de texto")
    self.__tipo_madera = tipo_madera

  def get_ubicacion(self):
    return self.__ubicacion

  def set_ubicacion(self, ubicacion):
    if not ubicacion or not isinstance(ubicacion, str):
      raise ValueError("La ubicación no puede estar vacía y debe ser una cadena de texto")
    self.__ubicacion = ubicacion

  def get_color(self):
    return self.__color

  def set_color(self, color):
    if not color or not isinstance(color, str):
      raise ValueError("El color no puede estar vacío y debe ser una cadena de texto")
    self.__color = color

  def get_propietario(self):
    return self.__propietario

  def set_propietario(self, propietario):
    if not propietario or not isinstance(propietario, str):
      raise ValueError("El propietario no puede estar vacío y debe ser una cadena de texto")
    self.__propietario = propietario

  def get_tamaño_mueble(self):
    return self.__tamaño_mueble

  def set_tamaño_mueble(self, tamaño_mueble):
    if tamaño_mueble < 0:
      raise ValueError("El tamaño del mueble no puede ser negativo")
    self.__tamaño_mueble = tamaño_mueble

Mueble1 = Mueble(1, "IKEA", 150.0, "Pino", "Sala", "Blanco", "Juan Perez", 2.5)


print(f"ID del mueble: {mueble1.get_id()}")
print(f"Proveedor: {mueble1.get_proveedor()}")
print(f"Precio: {mueble1.get_precio()}")


Mueble1.set_precio(175.50)
Mueble1.set_ubicacion("Dormitorio")

Mueble1.set_color("Gris")
Mueble1.set_propietario("Maria Garcia")

print(f"Nuevo precio: {mueble1.get_precio()}")
print(f"Nueva ubicación: {mueble1.get_ubicacion()}")
print(f"Nuevo color: {mueble1.get_color()}")
print(f"Nuevo propietario: {mueble1.get_propietario()}")

def main():
  print
# Out:
# ID del mueble: 1
# Proveedor: IKEA
# Precio: 150.0
# Nuevo precio: 175.5
# Nueva ubicación: Dormitorio
# Nuevo color: Gris
# Nuevo propietario: Maria Garcia
# Error al establecer ID: El id no puede ser negativo
# Error al establecer Proveedor: El proveedor no puede estar vacío y debe ser una cadena de texto
# Error al establecer Precio: El precio no puede ser negativo
# Error al establecer Tamaño del mueble: El tamaño del mueble no puede ser negativo

# %%
class Mueble:
    def __init__(self, id, proveedor, precio, tipo_madera, ubicacion, color, propietario, tamaño_mueble):
        self.__id = id
        self.__proveedor = proveedor
        self.__precio = precio
        self.__tipo_madera = tipo_madera
        self.__ubicacion = ubicacion
        self.__color = color
        self.__propietario = propietario
        self.__tamaño_mueble = tamaño_mueble

    def get_id(self):
        return self.__id

    def set_id(self, id):
        if id < 0:
            print("El id no puede ser negativo")
        else:
            self.__id = id

    def get_proveedor(self):
        return self.__proveedor

    def set_proveedor(self, proveedor):
        if not proveedor or not isinstance(proveedor, str):
            print("El proveedor no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__proveedor = proveedor

    def get_precio(self):
        return self.__precio

    def set_precio(self, precio):
        if precio < 0:
            print("El precio no puede ser negativo")
        else:
            self.__precio = precio

    def get_tipo_madera(self):
        return self.__tipo_madera

    def set_tipo_madera(self, tipo_madera):
        if not tipo_madera or not isinstance(tipo_madera, str):
            print("El tipo de madera no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__tipo_madera = tipo_madera

    def get_ubicacion(self):
        return self.__ubicacion

    def set_ubicacion(self, ubicacion):
        if not ubicacion or not isinstance(ubicacion, str):
            print("La ubicación no puede estar vacía y debe ser una cadena de texto")
        else:
            self.__ubicacion = ubicacion

    def get_color(self):
        return self.__color

    def set_color(self, color):
        if not color or not isinstance(color, str):
            print("El color no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__color = color

    def get_propietario(self):
        return self.__propietario

    def set_propietario(self, propietario):
        if not propietario or not isinstance(propietario, str):
            print("El propietario no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__propietario = propietario

    def get_tamaño_mueble(self):
        return self.__tamaño_mueble

    def set_tamaño_mueble(self, tamaño_mueble):
        if tamaño_mueble < 0:
            print("El tamaño del mueble no puede ser negativo")
        else:
            self.__tamaño_mueble = tamaño_mueble


def main():

    mueble1 = Mueble(1, "IKEA", 150.0, "Pino", "Sala", "Blanco", "Juan Perez", 2.5)
    mueble2 = Mueble(2, "HomeCenter", 320.0, "Roble", "Comedor", "Marrón", "Carlos López", 3.0)

    print("=== MUEBLE 1 ===")
    print(f"ID: {mueble1.get_id()}")
    print(f"Proveedor: {mueble1.get_proveedor()}")
    print(f"Precio: {mueble1.get_precio()}")
    print(f"Ubicación: {mueble1.get_ubicacion()}")
    print()

    print("=== MUEBLE 2 ===")
    print(f"ID: {mueble2.get_id()}")
    print(f"Proveedor: {mueble2.get_proveedor()}")
    print(f"Precio: {mueble2.get_precio()}")
    print(f"Ubicación: {mueble2.get_ubicacion()}")
    print()

    mueble2.set_precio(350.0)
    mueble2.set_color("Negro")

    print("=== MUEBLE 2 ACTUALIZADO ===")
    print(f"Nuevo precio: {mueble2.get_precio()}")
    print(f"Nuevo color: {mueble2.get_color()}")


if __name__ == "__main__":
    main()
# Out:
# ID del mueble: 1
# Proveedor: IKEA
# Precio: 150.0
# Nuevo precio: 175.5
# Nueva ubicación: Dormitorio
# Nuevo color: Gris
# Nuevo propietario: Maria Garcia
# El id no puede ser negativo
# El proveedor no puede estar vacío y debe ser una cadena de texto
# El precio no puede ser negativo
# El tamaño del mueble no puede ser negativo

# %%
class Mueble:
    def __init__(self, id, proveedor, precio, tipo_madera, ubicacion, color, propietario, tamaño_mueble):
        self.__id = id
        self.__proveedor = proveedor
        self.__precio = precio
        self.__tipo_madera = tipo_madera
        self.__ubicacion = ubicacion
        self.__color = color
        self.__propietario = propietario
        self.tamaño_mueble = tamaño_mueble


    @property
    def id(self):
        return self.__id

    @id.setter
    def id(self, value):
        if value < 0:
            print("El id no puede ser negativo")
        else:
            self.__id = value


    @property
    def proveedor(self):
        return self.__proveedor

    @proveedor.setter
    def proveedor(self, value):
        if not value or not isinstance(value, str):
            print("El proveedor no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__proveedor = value


    @property
    def precio(self):
        return self.__precio

    @precio.setter
    def precio(self, value):
        if value < 0:
            print("El precio no puede ser negativo")
        else:
            self.__precio = value


    @property
    def tipo_madera(self):
        return self.__tipo_madera

    @tipo_madera.setter
    def tipo_madera(self, value):
        if not value or not isinstance(value, str):
            print("El tipo de madera no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__tipo_madera = value


    @property
    def ubicacion(self):
        return self.__ubicacion

    @ubicacion.setter
    def ubicacion(self, value):
        if not value or not isinstance(value, str):
            print("La ubicación no puede estar vacía y debe ser una cadena de texto")
        else:
            self.__ubicacion = value


    @property
    def color(self):
        return self.__color

    @color.setter
    def color(self, value):
        if not value or not isinstance(value, str):
            print("El color no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__color = value


    @property
    def propietario(self):
        return self.__propietario

    @propietario.setter
    def propietario(self, value):
        if not value or not isinstance(value, str):
            print("El propietario no puede estar vacío y debe ser una cadena de texto")
        else:
            self.__propietario = value


    @property
    def tamaño_mueble(self):
        return self.__tamaño_mueble

    @tamaño_mueble.setter
    def tamaño_mueble(self, value):
        if value < 0:
            print("El tamaño del mueble no puede ser negativo")
        else:
            self.__tamaño_mueble = value


def main():

    mueble1 = Mueble(1, "IKEA", 150.0, "Pino", "Sala", "Blanco", "Juan Perez", 2.5)
    mueble2 = Mueble(2, "HomeCenter", 320.0, "Roble", "Comedor", "Marrón", "Carlos López", 3.0)

    print("=== MUEBLE 1 ===")
    print(f"ID: {mueble1.id}")
    print(f"Proveedor: {mueble1.proveedor}")
    print(f"Precio: {mueble1.precio}")
    print(f"Ubicación: {mueble1.ubicacion}")
    print()

    print("=== MUEBLE 2 ===")
    print(f"ID: {mueble2.id}")
    print(f"Proveedor: {mueble2.proveedor}")
    print(f"Precio: {mueble2.precio}")
    print(f"Ubicación: {mueble2.ubicacion}")
    print()

    mueble2.precio = 350.0
    mueble2.color = "Negro"

    print("=== MUEBLE 2 ACTUALIZADO ===")
    print(f"Nuevo precio: {mueble2.precio}")
    print(f"Nuevo color: {mueble2.color}")


if __name__ == "__main__":
    main()

# %%
from dataclasses import dataclass, field

@dataclass
class Mueble:
    id: int
    proveedor: str
    precio: float
    tipo_madera: str
    ubicacion: str
    color: str
    propietario: str
    tamaño_mueble: float

    def __post_init__(self):
        # Validaciones iniciales
        self.id = self.id
        self.proveedor = self.proveedor
        self.precio = self.precio
        self.tipo_madera = self.tipo_madera
        self.ubicacion = self.ubicacion
        self.color = self.color
        self.propietario = self.propietario
        self.tamaño_mueble = self.tamaño_mueble

    @property
    def id(self):
        return self._id

    @id.setter
    def id(self, value):
        if value < 0:
            raise ValueError("El id no puede ser negativo")
        self._id = value

    @property
    def proveedor(self):
        return self._proveedor

    @proveedor.setter
    def proveedor(self, value):
        if not value or not isinstance(value, str):
            raise ValueError("El proveedor no puede estar vacío y debe ser una cadena de texto")
        self._proveedor = value

    @property
    def precio(self):
        return self._precio

    @precio.setter
    def precio(self, value):
        if value < 0:
            raise ValueError("El precio no puede ser negativo")
        self._precio = value

    @property
    def tipo_madera(self):
        return self._tipo_madera

    @tipo_madera.setter
    def tipo_madera(self, value):
        if not value or not isinstance(value, str):
            raise ValueError("El tipo de madera no puede estar vacío y debe ser una cadena de texto")
        self._tipo_madera = value

    @property
    def ubicacion(self):
        return self._ubicacion

    @ubicacion.setter
    def ubicacion(self, value):
        if not value or not isinstance(value, str):
            raise ValueError("La ubicación no puede estar vacía y debe ser una cadena de texto")
        self._ubicacion = value

    @property
    def color(self):
        return self._color

    @color.setter
    def color(self, value):
        if not value or not isinstance(value, str):
            raise ValueError("El color no puede estar vacío y debe ser una cadena de texto")
        self._color = value

    @property
    def propietario(self):
        return self._propietario

    @propietario.setter
    def propietario(self, value):
        if not value or not isinstance(value, str):
            raise ValueError("El propietario no puede estar vacío y debe ser una cadena de texto")
        self._propietario = value

    @property
    def tamaño_mueble(self):
        return self._tamaño_mueble

    @tamaño_mueble.setter
    def tamaño_mueble(self, value):
        if value < 0:
            raise ValueError("El tamaño del mueble no puede ser negativo")
        self._tamaño_mueble = value


def main():
    mueble1 = Mueble(1, "IKEA", 150.0, "Pino", "Sala", "Blanco", "Juan Perez", 2.5)
    mueble2 = Mueble(2, "HomeCenter", 320.0, "Roble", "Comedor", "Marrón", "Carlos López", 3.0)

    print("=== MUEBLE 1 ===")
    print(f"ID: {mueble1.id}")
    print(f"Proveedor: {mueble1.proveedor}")
    print(f"Precio: {mueble1.precio}")
    print(f"Ubicación: {mueble1.ubicacion}")
    print()

    print("=== MUEBLE 2 ===")
    print(f"ID: {mueble2.id}")
    print(f"Proveedor: {mueble2.proveedor}")
    print(f"Precio: {mueble2.precio}")
    print(f"Ubicación: {mueble2.ubicacion}")
    print()

    mueble2.precio = 350.0
    mueble2.color = "Negro"

    print("=== MUEBLE 2 ACTUALIZADO ===")
    print(f"Nuevo precio: {mueble2.precio}")
    print(f"Nuevo color: {mueble2.color}")


if __name__ == "__main__":
    main()
