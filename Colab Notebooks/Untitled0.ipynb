# %%
print ("nombre")
print ("jpsiuuu")
# Out:
# nombre
# jpsiuuu

# %%
documento = input("ingrese numero de documento")
nombre = input("ingrese su nombre")
apellido = input("ingrese su apellido")
telefono = input("ingrese su numero de telefono")
direccion = input("ingrese direccion")
email = input("ingrese email")

print("/n==============DATOS PERSONALES=====================")
print(f"nombre completo: {nombre}{apellido}")
print(f"nombre de documento: {documento}")
print(f"numero de telefono: {telefono}")
print(f"direccion: {direccion}")
print(f"email: {email}")
print("=============================FIN DEL PROGRAMA===========")
# Out:
# ingrese numero de documento1023903265
# ingrese su nombrejuan
# ingrese su apellidopolania
# ingrese su numero de telefono3112311092
# ingrese direccioncalle 70 sur numero 15 50 este
# ingrese emailjuanpolnaireyes8@gmail.com
# /n==============DATOS PERSONALES=====================
# nombre completo: juanpolania
# nombre de documento: 1023903265
# numero de telefono: 3112311092
# direccion: calle 70 sur numero 15 50 este
# email: juanpolnaireyes8@gmail.com
# =============================FIN DEL PROGRAMA
